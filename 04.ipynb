# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da98da30-77a6-4754-aa6b-7fc8bf207acb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da98da30-77a6-4754-aa6b-7fc8bf207acb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import spacy
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
file_path = 'news_text (1).csv'
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

tokens = nltk.word_tokenize(text)[:500]
pos_tags_nltk = [tag for (word, tag) in nltk.pos_tag(tokens)]

nlp = spacy.load('en_core_web_sm')
doc = nlp(' '.join(tokens))

for ent in doc.ents:
    print(ent.text,  ent.label_)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Prince Philip Swear PERSON
# WXII ORG
# 12 CARDINAL
# Newsletters PRODUCT

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">`` abstract \'\' , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , \'\' and \n<mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Prince Philip Swear\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>\n</mark>\n By Shop the notebooks \'\' , \'\' and more that the royals ca n\'t live without . lifestyle \'\' , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , \'\' it nearly destroyed me . health \'\' , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , but there \'s a very good reason you should n\'t ignore them . The post How to Get Rid of Skin Tags , , , , ,
# ...

# %%
import nltk
# nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

file_path = r'C:\Users\rcoem\Downloads\News_letter1\news_text.csv'
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
sent = nltk.word_tokenize(text)[:200]
sent
# Out:
# ['news_id',
#  ',',
#  'title',
#  ',',
#  'abstract',
#  ',',
#  'category',
#  'N55528',
#  'The',
#  'Brands',
#  'Queen',
#  'Elizabeth',
#  ',',
#  'Prince',
#  'Charles',
#  ',',
#  'and',
#  'Prince',
#  'Philip',
#  'Swear',
#  'By',
#  'Shop',
#  'the',
#  'notebooks',
#  ',',
#  'jackets',
#  ',',
#  'and',
#  'more',
#  'that',
#  'the',
#  'royals',
#  'ca',
#  "n't",
#  'live',
#  'without',
#  '.',
#  'lifestyle',
#  'N19639',
#  '50',
#  'Worst',
#  'Habits',
#  'For',
#  'Belly',
#  'Fat',
#  'These',
#  'seemingly',
#  'harmless',
#  'habits',
#  'are',
#  'holding',
#  'you',
#  'back',
#  'and',
#  'keeping',
#  'you',
#  'from',
#  'shedding',
#  'that',
#  'unwanted',
#  'belly',
#  'fat',
#  'for',
#  'good',
#  '.',
#  'health',
#  'N61837',
#  'The',
#  'Cost',
#  'of',
#  'Trump',
#  "'s",
#  'Aid',
#  'Freeze',
#  'in',
#  'the',
#  'Trenches',
#  'of',
#  'Ukraine',
#  "'s",
#  'War',
#  'Lt.',
#  'Ivan',
#  'Molchanets',
#  'peeked',
#  'over',
#  'a',
# ...

# %%
import nltk
# nltk.download('averaged_perceptron_tagger')
sent1 = nltk.pos_tag(sent)
sent1
# Out:
# [('news_id', 'RB'),
#  (',', ','),
#  ('title', 'NN'),
#  (',', ','),
#  ('abstract', 'NN'),
#  (',', ','),
#  ('category', 'NN'),
#  ('N55528', 'NNP'),
#  ('The', 'DT'),
#  ('Brands', 'NNP'),
#  ('Queen', 'NNP'),
#  ('Elizabeth', 'NNP'),
#  (',', ','),
#  ('Prince', 'NNP'),
#  ('Charles', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Prince', 'NNP'),
#  ('Philip', 'NNP'),
#  ('Swear', 'NNP'),
#  ('By', 'IN'),
#  ('Shop', 'NNP'),
#  ('the', 'DT'),
#  ('notebooks', 'NNS'),
#  (',', ','),
#  ('jackets', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('more', 'JJR'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('royals', 'NNS'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('live', 'VB'),
#  ('without', 'IN'),
#  ('.', '.'),
#  ('lifestyle', 'JJ'),
#  ('N19639', 'NNP'),
#  ('50', 'CD'),
#  ('Worst', 'NNP'),
#  ('Habits', 'NNP'),
#  ('For', 'IN'),
#  ('Belly', 'NNP'),
#  ('Fat', 'NNP'),
#  ('These', 'DT'),
#  ('seemingly', 'RB'),
#  ('harmless', 'JJ'),
#  ('habits', 'NNS'),
#  ('are', 'VBP'),
# ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent1)
print(cs)
# Out:
# (S
#   news_id/RB
#   ,/,
#   (NP title/NN)
#   ,/,
#   (NP abstract/NN)
#   ,/,
#   (NP category/NN)
#   N55528/NNP
#   The/DT
#   Brands/NNP
#   Queen/NNP
#   Elizabeth/NNP
#   ,/,
#   Prince/NNP
#   Charles/NNP
#   ,/,
#   and/CC
#   Prince/NNP
#   Philip/NNP
#   Swear/NNP
#   By/IN
#   Shop/NNP
#   the/DT
#   notebooks/NNS
#   ,/,
#   jackets/NNS
#   ,/,
#   and/CC
#   more/JJR
#   that/IN
#   the/DT
#   royals/NNS
#   ca/MD
#   n't/RB
#   live/VB
#   without/IN
#   ./.
#   lifestyle/JJ
#   N19639/NNP
#   50/CD
#   Worst/NNP
#   Habits/NNP
#   For/IN
#   Belly/NNP
#   Fat/NNP
#   These/DT
#   seemingly/RB
#   harmless/JJ
#   habits/NNS
#   are/VBP
#   holding/VBG
#   you/PRP
#   back/RB
#   and/CC
#   keeping/VBG
#   you/PRP
#   from/IN
#   shedding/VBG
#   that/IN
#   unwanted/JJ
#   belly/RB
#   fat/JJ
#   for/IN
#   good/JJ
#   ./.
#   (NP health/NN)
#   N61837/NNP
#   The/DT
#   Cost/NNP
#   of/IN
#   Trump/NNP
#   's/POS
#   (NP Aid/NN)
#   (NP Freeze/NN)
#   in/IN
# ...

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('news_id', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('title', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('abstract', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('category', 'NN', 'B-NP'),
#  ('N55528', 'NNP', 'O'),
#  ('The', 'DT', 'O'),
#  ('Brands', 'NNP', 'O'),
#  ('Queen', 'NNP', 'O'),
#  ('Elizabeth', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Prince', 'NNP', 'O'),
#  ('Charles', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('Prince', 'NNP', 'O'),
#  ('Philip', 'NNP', 'O'),
#  ('Swear', 'NNP', 'O'),
#  ('By', 'IN', 'O'),
#  ('Shop', 'NNP', 'O'),
#  ('the', 'DT', 'O'),
#  ('notebooks', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('jackets', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('more', 'JJR', 'O'),
#  ('that', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('royals', 'NNS', 'O'),
#  ('ca', 'MD', 'O'),
#  ("n't", 'RB', 'O'),
#  ('live', 'VB', 'O'),
#  ('without', 'IN', 'O'),
#  ('.', '.', 'O'),
#  ('lifestyle', 'JJ', 'O'),
#  ('N19639', 'NNP', 'O'),
#  ('50', 'CD', 'O'),
# ...

# %%
import nltk
# nltk.download('words')
# nltk.download('maxent_ne_chunker')/
ne_tree = nltk.ne_chunk(pos_tag(sent))
print(ne_tree)
# Out:
# (S
#   news_id/RB
#   ,/,
#   title/NN
#   ,/,
#   abstract/NN
#   ,/,
#   category/NN
#   N55528/NNP
#   The/DT
#   (ORGANIZATION Brands/NNP Queen/NNP Elizabeth/NNP)
#   ,/,
#   (PERSON Prince/NNP Charles/NNP)
#   ,/,
#   and/CC
#   (ORGANIZATION Prince/NNP Philip/NNP Swear/NNP By/IN Shop/NNP)
#   the/DT
#   notebooks/NNS
#   ,/,
#   jackets/NNS
#   ,/,
#   and/CC
#   more/JJR
#   that/IN
#   the/DT
#   royals/NNS
#   ca/MD
#   n't/RB
#   live/VB
#   without/IN
#   ./.
#   lifestyle/JJ
#   N19639/NNP
#   50/CD
#   Worst/NNP
#   Habits/NNP
#   For/IN
#   (PERSON Belly/NNP Fat/NNP)
#   These/DT
#   seemingly/RB
#   harmless/JJ
#   habits/NNS
#   are/VBP
#   holding/VBG
#   you/PRP
#   back/RB
#   and/CC
#   keeping/VBG
#   you/PRP
#   from/IN
#   shedding/VBG
#   that/IN
#   unwanted/JJ
#   belly/RB
#   fat/JJ
#   for/IN
#   good/JJ
#   ./.
#   health/NN
#   N61837/NNP
#   The/DT
#   (ORGANIZATION Cost/NNP)
#   of/IN
#   (PERSON Trump/NNP)
#   's/POS
#   Aid/NN
#   (PERSON Freeze/NN)
# ...
